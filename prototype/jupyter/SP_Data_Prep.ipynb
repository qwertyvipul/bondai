# %%
# Mount Google Drive
"""
No need to execute this block when working on local system.
"""
from google.colab import drive
drive.mount("/content/vdrive", force_remount = True)
# Out:
# Mounted at /content/vdrive

# %%
# Files to process
"""
Modify the locations below as per your directory struture.
"""
root_dir = "/content/vdrive/My Drive/Colab Notebooks/Projects/Bondai/SP 500/data/"
data_dir = "/content/vdrive/My Drive/Colab Notebooks/Projects/Bondai/SP 500/data/raw/"
prep_dir = "/content/vdrive/My Drive/Colab Notebooks/Projects/Bondai/SP 500/data/prep/"

# %%
# Loading the csv tickers file
import pandas as pd
ticker_list_df = pd.read_csv(root_dir + "ticker_list.csv", header=None, names=["Tickers"])

# %%
def prep_data(ticker):
    # INCOME STATEMENT
    income_statement = pd.read_excel(data_dir + ticker + ".xlsx", sheet_name = "income_statement")
    income_statement = income_statement.loc[["Gross Profit", "Operating Income", "Net Income"]]
    income_statement.rename(index = {
        "Gross Profit": "gross_profit",
        "Operating Income": "op_income",
        "Net Income": "net_income"
    }, inplace = True)
    
    # BALANCE SHEET
    balance_sheet = pd.read_excel(data_dir + ticker + ".xlsx", sheet_name = "balance_sheet")
    balance_sheet = balance_sheet.loc[["Total current assets", "Total non-current assets", "Total current liabilities", "Total non-current liabilities"]]
    balance_sheet.rename(index = {
        "Total current assets": "crr_asst",
        "Total non-current assets": "ncrr_asst",
        "Total current liabilities": "crr_libt",
        "Total non-current liabilities": "ncrr_libt"
    }, inplace = True)
    
    df = pd.concat([income_statement, balance_sheet])
    df = df[df.columns[::-1]]
    df = df.transpose()
    df = (df - df.shift(1))/abs(df.shift(1))
    df *= 100
    df.dropna(inplace = True)
    df = df[["net_income", "op_income", "gross_profit", "crr_asst", "ncrr_asst", "crr_libt", "ncrr_libt"]]
#     print(df)
    df.to_csv(prep_dir + ticker + ".csv")
    return

# prep_data("AES")

# %%
# the companies for which balance sheet without current and non-current assets and liabilities
def prep_data_2(ticker):
    # INCOME STATEMENT
    income_statement = pd.read_excel(data_dir + ticker + ".xlsx", sheet_name = "income_statement")
    income_statement = income_statement.loc[["Gross Profit", "Operating Income", "Net Income"]]
    income_statement.rename(index = {
        "Gross Profit": "gross_profit",
        "Operating Income": "op_income",
        "Net Income": "net_income"
    }, inplace = True)
    
    # BALANCE SHEET
    balance_sheet = pd.read_excel(data_dir + ticker + ".xlsx", sheet_name = "balance_sheet")
    balance_sheet = balance_sheet.loc[["Total assets", "Total liabilities"]]
    balance_sheet.rename(index = {
        "Total assets": "ncrr_asst",
        "Total liabilities": "ncrr_libt"
    }, inplace = True)
    
    df = pd.concat([income_statement, balance_sheet])
    df = df[df.columns[::-1]]
    df = df.transpose()
    df = (df - df.shift(1))/abs(df.shift(1))
    df *= 100
    df.dropna(inplace = True)
    df.insert(0, "crr_asst", 0)
    df.insert(0, "crr_libt", 0)
    df = df[["net_income", "op_income", "gross_profit", "crr_asst", "ncrr_asst", "crr_libt", "ncrr_libt"]]
    df.to_csv(prep_dir + ticker + ".csv")
    return

# %%
counter = 0
not_done_set = set()
for ticker in ticker_list_df["Tickers"]:
    counter += 1
    try:
        print("Pre Processing Data for: " + ticker + "(" + str(counter) + "/"+ str(len(ticker_list_df)) +"; Failed(" + str(len(not_done_set)) + "))")
        prep_data(ticker)
    except:
        try:
            print("--------------------------------------------------")
            prep_data_2(ticker)
        except Exception as e:
            print(e)
            print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
            not_done_set.add(ticker)
# Out:
# Pre Processing Data for: HSIC(1/482; Failed(0))
# Pre Processing Data for: ALXN(2/482; Failed(0))
# Pre Processing Data for: KR(3/482; Failed(0))
# Pre Processing Data for: BBT(4/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: DIS(5/482; Failed(0))
# Pre Processing Data for: MMC(6/482; Failed(0))
# Pre Processing Data for: MAR(7/482; Failed(0))
# Pre Processing Data for: CELG(8/482; Failed(0))
# Pre Processing Data for: VMC(9/482; Failed(0))
# Pre Processing Data for: RHI(10/482; Failed(0))
# Pre Processing Data for: MKC(11/482; Failed(0))
# Pre Processing Data for: PGR(12/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ILMN(13/482; Failed(0))
# Pre Processing Data for: AMAT(14/482; Failed(0))
# Pre Processing Data for: LEG(15/482; Failed(0))
# Pre Processing Data for: STI(16/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: GS(17/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: RTN(18/482; Failed(0))
# Pre Processing Data for: KMI(19/482; Failed(0))
# Pre Processing Data for: CRM(20/482; Failed(0))
# Pre Processing Data for: STZ(21/482; Failed(0))
# Pre Processing Data for: INFO(22/482; Failed(0))
# Pre Processing Data for: AAP(23/482; Failed(0))
# Pre Processing Data for: EXC(24/482; Failed(0))
# Pre Processing Data for: MCO(25/482; Failed(0))
# Pre Processing Data for: AGN(26/482; Failed(0))
# Pre Processing Data for: C(27/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: NTRS(28/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: TMK(29/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: EW(30/482; Failed(0))
# Pre Processing Data for: NEE(31/482; Failed(0))
# Pre Processing Data for: BBY(32/482; Failed(0))
# Pre Processing Data for: RCL(33/482; Failed(0))
# Pre Processing Data for: VIAB(34/482; Failed(0))
# Pre Processing Data for: TTWO(35/482; Failed(0))
# Pre Processing Data for: AWK(36/482; Failed(0))
# Pre Processing Data for: MO(37/482; Failed(0))
# Pre Processing Data for: WAT(38/482; Failed(0))
# Pre Processing Data for: EQR(39/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MA(40/482; Failed(0))
# Pre Processing Data for: TGT(41/482; Failed(0))
# Pre Processing Data for: DG(42/482; Failed(0))
# Pre Processing Data for: JPM(43/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: IT(44/482; Failed(0))
# Pre Processing Data for: LYB(45/482; Failed(0))
# Pre Processing Data for: ISRG(46/482; Failed(0))
# Pre Processing Data for: ABC(47/482; Failed(0))
# Pre Processing Data for: FCX(48/482; Failed(0))
# Pre Processing Data for: ETR(49/482; Failed(0))
# Pre Processing Data for: LB(50/482; Failed(0))
# Pre Processing Data for: GWW(51/482; Failed(0))
# Pre Processing Data for: GT(52/482; Failed(0))
# Pre Processing Data for: CF(53/482; Failed(0))
# Pre Processing Data for: DVA(54/482; Failed(0))
# Pre Processing Data for: CAH(55/482; Failed(0))
# Pre Processing Data for: ADP(56/482; Failed(0))
# Pre Processing Data for: CAG(57/482; Failed(0))
# Pre Processing Data for: YUM(58/482; Failed(0))
# Pre Processing Data for: D(59/482; Failed(0))
# Pre Processing Data for: CL(60/482; Failed(0))
# Pre Processing Data for: PRGO(61/482; Failed(0))
# Pre Processing Data for: AZO(62/482; Failed(0))
# Pre Processing Data for: ETFC(63/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: IP(64/482; Failed(0))
# Pre Processing Data for: COF(65/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: GPS(66/482; Failed(0))
# Pre Processing Data for: FL(67/482; Failed(0))
# Pre Processing Data for: GD(68/482; Failed(0))
# Pre Processing Data for: CVS(69/482; Failed(0))
# Pre Processing Data for: ED(70/482; Failed(0))
# Pre Processing Data for: CI(71/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: PNC(72/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: BLK(73/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HUM(74/482; Failed(0))
# Pre Processing Data for: MMM(75/482; Failed(0))
# Pre Processing Data for: ALGN(76/482; Failed(0))
# Pre Processing Data for: AFL(77/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: CHTR(78/482; Failed(0))
# Pre Processing Data for: CSX(79/482; Failed(0))
# Pre Processing Data for: ORLY(80/482; Failed(0))
# Pre Processing Data for: CNC(81/482; Failed(0))
# Pre Processing Data for: MDLZ(82/482; Failed(0))
# Pre Processing Data for: SHW(83/482; Failed(0))
# Pre Processing Data for: WRK(84/482; Failed(0))
# Pre Processing Data for: WU(85/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: GOOGL(86/482; Failed(0))
# Pre Processing Data for: FOX(87/482; Failed(0))
# Pre Processing Data for: NWSA(88/482; Failed(0))
# Pre Processing Data for: CB(89/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ADM(90/482; Failed(0))
# Pre Processing Data for: RF(91/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: DPS(92/482; Failed(0))
# Pre Processing Data for: RJF(93/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: NOV(94/482; Failed(0))
# Pre Processing Data for: FLIR(95/482; Failed(0))
# Pre Processing Data for: APH(96/482; Failed(0))
# Pre Processing Data for: EMR(97/482; Failed(0))
# Pre Processing Data for: WM(98/482; Failed(0))
# Pre Processing Data for: IPG(99/482; Failed(0))
# Pre Processing Data for: PPG(100/482; Failed(0))
# Pre Processing Data for: REG(101/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ZTS(102/482; Failed(0))
# Pre Processing Data for: AIG(103/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: CTXS(104/482; Failed(0))
# Pre Processing Data for: HBI(105/482; Failed(0))
# Pre Processing Data for: LKQ(106/482; Failed(0))
# Pre Processing Data for: EIX(107/482; Failed(0))
# Pre Processing Data for: SNPS(108/482; Failed(0))
# Pre Processing Data for: APD(109/482; Failed(0))
# Pre Processing Data for: MET(110/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: RE(111/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: KMB(112/482; Failed(0))
# Pre Processing Data for: PNR(113/482; Failed(0))
# Pre Processing Data for: WMB(114/482; Failed(0))
# Pre Processing Data for: MPC(115/482; Failed(0))
# Pre Processing Data for: TSS(116/482; Failed(0))
# Pre Processing Data for: NI(117/482; Failed(0))
# Pre Processing Data for: DRE(118/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ORCL(119/482; Failed(0))
# Pre Processing Data for: ALK(120/482; Failed(0))
# Pre Processing Data for: SPGI(121/482; Failed(0))
# Pre Processing Data for: F(122/482; Failed(0))
# Pre Processing Data for: HSY(123/482; Failed(0))
# Pre Processing Data for: SEE(124/482; Failed(0))
# Pre Processing Data for: CTL(125/482; Failed(0))
# Pre Processing Data for: CMA(126/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: JWN(127/482; Failed(0))
# Pre Processing Data for: BKNG(128/482; Failed(0))
# Pre Processing Data for: DTE(129/482; Failed(0))
# Pre Processing Data for: ALLE(130/482; Failed(0))
# Pre Processing Data for: HAL(131/482; Failed(0))
# Pre Processing Data for: JBHT(132/482; Failed(0))
# Pre Processing Data for: FAST(133/482; Failed(0))
# Pre Processing Data for: EL(134/482; Failed(0))
# Pre Processing Data for: A(135/482; Failed(0))
# Pre Processing Data for: LNC(136/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: WELL(137/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HON(138/482; Failed(0))
# Pre Processing Data for: DISCA(139/482; Failed(0))
# Pre Processing Data for: AEP(140/482; Failed(0))
# Pre Processing Data for: XOM(141/482; Failed(0))
# Pre Processing Data for: XEC(142/482; Failed(0))
# Pre Processing Data for: GLW(143/482; Failed(0))
# Pre Processing Data for: NRG(144/482; Failed(0))
# Pre Processing Data for: NTAP(145/482; Failed(0))
# Pre Processing Data for: AMP(146/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MYL(147/482; Failed(0))
# Pre Processing Data for: ADBE(148/482; Failed(0))
# Pre Processing Data for: LEN(149/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: DWDP(150/482; Failed(0))
# Pre Processing Data for: DRI(151/482; Failed(0))
# Pre Processing Data for: MDT(152/482; Failed(0))
# Pre Processing Data for: CMG(153/482; Failed(0))
# Pre Processing Data for: FITB(154/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: REGN(155/482; Failed(0))
# Pre Processing Data for: AVB(156/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: VFC(157/482; Failed(0))
# Pre Processing Data for: BHF(158/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MHK(159/482; Failed(0))
# Pre Processing Data for: DVN(160/482; Failed(0))
# Pre Processing Data for: WMT(161/482; Failed(0))
# Pre Processing Data for: UNH(162/482; Failed(0))
# Pre Processing Data for: BIIB(163/482; Failed(0))
# Pre Processing Data for: PKI(164/482; Failed(0))
# Pre Processing Data for: HRB(165/482; Failed(0))
# Pre Processing Data for: EQIX(166/482; Failed(0))
# Pre Processing Data for: FFIV(167/482; Failed(0))
# Pre Processing Data for: ALB(168/482; Failed(0))
# Pre Processing Data for: SIVB(169/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: COTY(170/482; Failed(0))
# Pre Processing Data for: UDR(171/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: KSS(172/482; Failed(0))
# Pre Processing Data for: PRU(173/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: PXD(174/482; Failed(0))
# Pre Processing Data for: URI(175/482; Failed(0))
# Pre Processing Data for: AAL(176/482; Failed(0))
# Pre Processing Data for: EFX(177/482; Failed(0))
# Pre Processing Data for: IR(178/482; Failed(0))
# Pre Processing Data for: WYNN(179/482; Failed(0))
# Pre Processing Data for: VNO(180/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: AOS(181/482; Failed(0))
# Pre Processing Data for: KLAC(182/482; Failed(0))
# Pre Processing Data for: CPB(183/482; Failed(0))
# Pre Processing Data for: BSX(184/482; Failed(0))
# Pre Processing Data for: PM(185/482; Failed(0))
# Pre Processing Data for: SWKS(186/482; Failed(0))
# Pre Processing Data for: SLB(187/482; Failed(0))
# Pre Processing Data for: AAPL(188/482; Failed(0))
# Pre Processing Data for: AMG(189/482; Failed(0))
# Pre Processing Data for: AMD(190/482; Failed(0))
# Pre Processing Data for: CMI(191/482; Failed(0))
# Pre Processing Data for: T(192/482; Failed(0))
# Pre Processing Data for: TEL(193/482; Failed(0))
# Pre Processing Data for: NVDA(194/482; Failed(0))
# Pre Processing Data for: JNPR(195/482; Failed(0))
# Pre Processing Data for: CTSH(196/482; Failed(0))
# Pre Processing Data for: AMGN(197/482; Failed(0))
# Pre Processing Data for: DLR(198/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: BEN(199/482; Failed(0))
# Pre Processing Data for: MSI(200/482; Failed(0))
# Pre Processing Data for: WHR(201/482; Failed(0))
# Pre Processing Data for: AYI(202/482; Failed(0))
# Pre Processing Data for: IPGP(203/482; Failed(0))
# Pre Processing Data for: BLL(204/482; Failed(0))
# Pre Processing Data for: PCAR(205/482; Failed(0))
# Pre Processing Data for: COO(206/482; Failed(0))
# Pre Processing Data for: WFC(207/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: RRC(208/482; Failed(0))
# Pre Processing Data for: HCA(209/482; Failed(0))
# Pre Processing Data for: COST(210/482; Failed(0))
# Pre Processing Data for: PSX(211/482; Failed(0))
# Pre Processing Data for: CMS(212/482; Failed(0))
# Pre Processing Data for: RSG(213/482; Failed(0))
# Pre Processing Data for: DAL(214/482; Failed(0))
# Pre Processing Data for: IVZ(215/482; Failed(0))
# Pre Processing Data for: AJG(216/482; Failed(0))
# Pre Processing Data for: PWR(217/482; Failed(0))
# Pre Processing Data for: IFF(218/482; Failed(0))
# Pre Processing Data for: MRK(219/482; Failed(0))
# Pre Processing Data for: ICE(220/482; Failed(0))
# Pre Processing Data for: SYY(221/482; Failed(0))
# Pre Processing Data for: PH(222/482; Failed(0))
# Pre Processing Data for: TAP(223/482; Failed(0))
# Pre Processing Data for: VAR(224/482; Failed(0))
# Pre Processing Data for: BHGE(225/482; Failed(0))
# Pre Processing Data for: FBHS(226/482; Failed(0))
# Pre Processing Data for: SBAC(227/482; Failed(0))
# Pre Processing Data for: WLTW(228/482; Failed(0))
# Pre Processing Data for: ABT(229/482; Failed(0))
# Pre Processing Data for: ARE(230/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: VTR(231/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: JCI(232/482; Failed(0))
# Pre Processing Data for: IDXX(233/482; Failed(0))
# Pre Processing Data for: AEE(234/482; Failed(0))
# Pre Processing Data for: AXP(235/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: VRSN(236/482; Failed(0))
# Pre Processing Data for: SJM(237/482; Failed(0))
# Pre Processing Data for: BK(238/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HPQ(239/482; Failed(0))
# Pre Processing Data for: SYF(240/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MS(241/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: SWK(242/482; Failed(0))
# Pre Processing Data for: INTU(243/482; Failed(0))
# Pre Processing Data for: AES(244/482; Failed(0))
# Pre Processing Data for: HP(245/482; Failed(0))
# Pre Processing Data for: KIM(246/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: BMY(247/482; Failed(0))
# Pre Processing Data for: PVH(248/482; Failed(0))
# Pre Processing Data for: RL(249/482; Failed(0))
# Pre Processing Data for: WDC(250/482; Failed(0))
# Pre Processing Data for: NLSN(251/482; Failed(0))
# Pre Processing Data for: CBS(252/482; Failed(0))
# Pre Processing Data for: ROP(253/482; Failed(0))
# Pre Processing Data for: TXN(254/482; Failed(0))
# Pre Processing Data for: AIV(255/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: APA(256/482; Failed(0))
# Pre Processing Data for: NFLX(257/482; Failed(0))
# Pre Processing Data for: PBCT(258/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MAA(259/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: TJX(260/482; Failed(0))
# Pre Processing Data for: UAL(261/482; Failed(0))
# Pre Processing Data for: FDX(262/482; Failed(0))
# Pre Processing Data for: JEC(263/482; Failed(0))
# Pre Processing Data for: ATVI(264/482; Failed(0))
# Pre Processing Data for: UNM(265/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: USB(266/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: KMX(267/482; Failed(0))
# Pre Processing Data for: QCOM(268/482; Failed(0))
# Pre Processing Data for: UHS(269/482; Failed(0))
# Pre Processing Data for: ADSK(270/482; Failed(0))
# Pre Processing Data for: HCP(271/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: CAT(272/482; Failed(0))
# Pre Processing Data for: NUE(273/482; Failed(0))
# Pre Processing Data for: AME(274/482; Failed(0))
# Pre Processing Data for: TROW(275/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: AON(276/482; Failed(0))
# Pre Processing Data for: XEL(277/482; Failed(0))
# Pre Processing Data for: V(278/482; Failed(0))
# Pre Processing Data for: AIZ(279/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ADI(280/482; Failed(0))
# Pre Processing Data for: LNT(281/482; Failed(0))
# Pre Processing Data for: FOXA(282/482; Failed(0))
# Pre Processing Data for: CVX(283/482; Failed(0))
# Pre Processing Data for: CCI(284/482; Failed(0))
# Pre Processing Data for: NKE(285/482; Failed(0))
# Pre Processing Data for: ZION(286/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: AMT(287/482; Failed(0))
# Pre Processing Data for: MAS(288/482; Failed(0))
# Pre Processing Data for: SNA(289/482; Failed(0))
# Pre Processing Data for: GE(290/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: UTX(291/482; Failed(0))
# Pre Processing Data for: WY(292/482; Failed(0))
# Pre Processing Data for: RMD(293/482; Failed(0))
# Pre Processing Data for: QRVO(294/482; Failed(0))
# Pre Processing Data for: KHC(295/482; Failed(0))
# Pre Processing Data for: XRX(296/482; Failed(0))
# Pre Processing Data for: EQT(297/482; Failed(0))
# Pre Processing Data for: MAC(298/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: VRSK(299/482; Failed(0))
# Pre Processing Data for: MOS(300/482; Failed(0))
# Pre Processing Data for: ROK(301/482; Failed(0))
# Pre Processing Data for: UPS(302/482; Failed(0))
# Pre Processing Data for: FB(303/482; Failed(0))
# Pre Processing Data for: UAA(304/482; Failed(0))
# Pre Processing Data for: KSU(305/482; Failed(0))
# Pre Processing Data for: EBAY(306/482; Failed(0))
# Pre Processing Data for: NDAQ(307/482; Failed(0))
# Pre Processing Data for: DHR(308/482; Failed(0))
# Pre Processing Data for: ES(309/482; Failed(0))
# Pre Processing Data for: PPL(310/482; Failed(0))
# Pre Processing Data for: SO(311/482; Failed(0))
# Pre Processing Data for: CMCSA(312/482; Failed(0))
# Pre Processing Data for: EMN(313/482; Failed(0))
# Pre Processing Data for: ITW(314/482; Failed(0))
# Pre Processing Data for: OMC(315/482; Failed(0))
# Pre Processing Data for: CHRW(316/482; Failed(0))
# Pre Processing Data for: DFS(317/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: CLX(318/482; Failed(0))
# Pre Processing Data for: PEG(319/482; Failed(0))
# Pre Processing Data for: DGX(320/482; Failed(0))
# Pre Processing Data for: PYPL(321/482; Failed(0))
# Pre Processing Data for: CSCO(322/482; Failed(0))
# Pre Processing Data for: GPN(323/482; Failed(0))
# Pre Processing Data for: CBRE(324/482; Failed(0))
# Pre Processing Data for: LRCX(325/482; Failed(0))
# Pre Processing Data for: ADS(326/482; Failed(0))
# Pre Processing Data for: HII(327/482; Failed(0))
# Pre Processing Data for: CERN(328/482; Failed(0))
# Pre Processing Data for: NAVI(329/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: FMC(330/482; Failed(0))
# Pre Processing Data for: LMT(331/482; Failed(0))
# Pre Processing Data for: APC(332/482; Failed(0))
# Pre Processing Data for: FRT(333/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ANSS(334/482; Failed(0))
# Pre Processing Data for: NEM(335/482; Failed(0))
# Pre Processing Data for: TMO(336/482; Failed(0))
# Pre Processing Data for: CHD(337/482; Failed(0))
# Pre Processing Data for: PNW(338/482; Failed(0))
# Pre Processing Data for: AMZN(339/482; Failed(0))
# Pre Processing Data for: DXC(340/482; Failed(0))
# Pre Processing Data for: NBL(341/482; Failed(0))
# Pre Processing Data for: AVGO(342/482; Failed(0))
# Pre Processing Data for: FIS(343/482; Failed(0))
# Pre Processing Data for: TDG(344/482; Failed(0))
# Pre Processing Data for: KEY(345/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HST(346/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MCHP(347/482; Failed(0))
# Pre Processing Data for: ACN(348/482; Failed(0))
# Pre Processing Data for: AVY(349/482; Failed(0))
# Pre Processing Data for: SCHW(350/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: DE(351/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ESS(352/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: PHM(353/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: TSN(354/482; Failed(0))
# Pre Processing Data for: CDNS(355/482; Failed(0))
# Pre Processing Data for: O(356/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HD(357/482; Failed(0))
# Pre Processing Data for: PCG(358/482; Failed(0))
# Pre Processing Data for: XLNX(359/482; Failed(0))
# Pre Processing Data for: LUV(360/482; Failed(0))
# Pre Processing Data for: HES(361/482; Failed(0))
# Pre Processing Data for: SYMC(362/482; Failed(0))
# Pre Processing Data for: ALL(363/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HPE(364/482; Failed(0))
# Pre Processing Data for: HIG(365/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: PAYX(366/482; Failed(0))
# Pre Processing Data for: PG(367/482; Failed(0))
# Pre Processing Data for: TPR(368/482; Failed(0))
# Pre Processing Data for: JNJ(369/482; Failed(0))
# Pre Processing Data for: ETN(370/482; Failed(0))
# Pre Processing Data for: MSFT(371/482; Failed(0))
# Pre Processing Data for: DISH(372/482; Failed(0))
# Pre Processing Data for: MU(373/482; Failed(0))
# Pre Processing Data for: GRMN(374/482; Failed(0))
# Pre Processing Data for: EXPE(375/482; Failed(0))
# Pre Processing Data for: CBOE(376/482; Failed(0))
# Pre Processing Data for: K(377/482; Failed(0))
# Pre Processing Data for: FLR(378/482; Failed(0))
# Pre Processing Data for: ECL(379/482; Failed(0))
# Pre Processing Data for: M(380/482; Failed(0))
# Pre Processing Data for: L(381/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: AKAM(382/482; Failed(0))
# Pre Processing Data for: BWA(383/482; Failed(0))
# Pre Processing Data for: MRO(384/482; Failed(0))
# Pre Processing Data for: VLO(385/482; Failed(0))
# Pre Processing Data for: DHI(386/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: DUK(387/482; Failed(0))
# Pre Processing Data for: LLL(388/482; Failed(0))
# Pre Processing Data for: GILD(389/482; Failed(0))
# Pre Processing Data for: GIS(390/482; Failed(0))
# Pre Processing Data for: LH(391/482; Failed(0))
# Pre Processing Data for: APTV(392/482; Failed(0))
# Pre Processing Data for: DLTR(393/482; Failed(0))
# Pre Processing Data for: STT(394/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MGM(395/482; Failed(0))
# Pre Processing Data for: CCL(396/482; Failed(0))
# Pre Processing Data for: STX(397/482; Failed(0))
# Pre Processing Data for: LLY(398/482; Failed(0))
# Pre Processing Data for: BDX(399/482; Failed(0))
# Pre Processing Data for: PFG(400/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: MCK(401/482; Failed(0))
# Pre Processing Data for: VRTX(402/482; Failed(0))
# Pre Processing Data for: RHT(403/482; Failed(0))
# Pre Processing Data for: MTB(404/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: EXPD(405/482; Failed(0))
# Pre Processing Data for: BAX(406/482; Failed(0))
# Pre Processing Data for: HRS(407/482; Failed(0))
# Pre Processing Data for: BAC(408/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: TRV(409/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: FE(410/482; Failed(0))
# Pre Processing Data for: NWL(411/482; Failed(0))
# Pre Processing Data for: GPC(412/482; Failed(0))
# Pre Processing Data for: CME(413/482; Failed(0))
# Pre Processing Data for: HAS(414/482; Failed(0))
# Pre Processing Data for: TXT(415/482; Failed(0))
# Pre Processing Data for: LOW(416/482; Failed(0))
# Pre Processing Data for: HOG(417/482; Failed(0))
# Pre Processing Data for: CNP(418/482; Failed(0))
# Pre Processing Data for: FLS(419/482; Failed(0))
# Pre Processing Data for: HLT(420/482; Failed(0))
# Pre Processing Data for: TSCO(421/482; Failed(0))
# Pre Processing Data for: CTAS(422/482; Failed(0))
# Pre Processing Data for: SRCL(423/482; Failed(0))
# Pre Processing Data for: TIF(424/482; Failed(0))
# Pre Processing Data for: MNST(425/482; Failed(0))
# Pre Processing Data for: EXR(426/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: IQV(427/482; Failed(0))
# Pre Processing Data for: IBM(428/482; Failed(0))
# Pre Processing Data for: SPG(429/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: XRAY(430/482; Failed(0))
# Pre Processing Data for: VZ(431/482; Failed(0))
# Pre Processing Data for: ULTA(432/482; Failed(0))
# Pre Processing Data for: NCLH(433/482; Failed(0))
# Pre Processing Data for: FTI(434/482; Failed(0))
# Pre Processing Data for: MAT(435/482; Failed(0))
# Pre Processing Data for: PLD(436/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: COP(437/482; Failed(0))
# Pre Processing Data for: FTV(438/482; Failed(0))
# Pre Processing Data for: CINF(439/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ABBV(440/482; Failed(0))
# Pre Processing Data for: PEP(441/482; Failed(0))
# Pre Processing Data for: MTD(442/482; Failed(0))
# Pre Processing Data for: PSA(443/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: PFE(444/482; Failed(0))
# Pre Processing Data for: XYL(445/482; Failed(0))
# Pre Processing Data for: SRE(446/482; Failed(0))
# Pre Processing Data for: WEC(447/482; Failed(0))
# Pre Processing Data for: ANTM(448/482; Failed(0))
# Pre Processing Data for: TRIP(449/482; Failed(0))
# Pre Processing Data for: OKE(450/482; Failed(0))
# Pre Processing Data for: MCD(451/482; Failed(0))
# Pre Processing Data for: INCY(452/482; Failed(0))
# Pre Processing Data for: ARNC(453/482; Failed(0))
# Pre Processing Data for: ZBH(454/482; Failed(0))
# Pre Processing Data for: BXP(455/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: ROST(456/482; Failed(0))
# Pre Processing Data for: CXO(457/482; Failed(0))
# Pre Processing Data for: MLM(458/482; Failed(0))
# Pre Processing Data for: NSC(459/482; Failed(0))
# Pre Processing Data for: COG(460/482; Failed(0))
# Pre Processing Data for: OXY(461/482; Failed(0))
# Pre Processing Data for: EA(462/482; Failed(0))
# Pre Processing Data for: GM(463/482; Failed(0))
# Pre Processing Data for: HOLX(464/482; Failed(0))
# Pre Processing Data for: SLG(465/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: HBAN(466/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: IRM(467/482; Failed(0))
# Pre Processing Data for: BA(468/482; Failed(0))
# Pre Processing Data for: DOV(469/482; Failed(0))
# Pre Processing Data for: SBUX(470/482; Failed(0))
# Pre Processing Data for: PKG(471/482; Failed(0))
# Pre Processing Data for: KO(472/482; Failed(0))
# Pre Processing Data for: CFG(473/482; Failed(0))
# --------------------------------------------------
# Pre Processing Data for: WBA(474/482; Failed(0))
# Pre Processing Data for: NOC(475/482; Failed(0))
# Pre Processing Data for: EOG(476/482; Failed(0))
# Pre Processing Data for: FISV(477/482; Failed(0))
# Pre Processing Data for: NKTR(478/482; Failed(0))
# Pre Processing Data for: INTC(479/482; Failed(0))
# Pre Processing Data for: UNP(480/482; Failed(0))
# Pre Processing Data for: SYK(481/482; Failed(0))
# Pre Processing Data for: HRL(482/482; Failed(0))

# %% [markdown]
# ### References
#
# 1. http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.insert.html
