# %% [markdown]
# # SP_Dataset_Framework

# %% [markdown]
# ### Data
# 1. Company Financials
# 2. Company Stock Prices

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/vdrive", force_remount = True)
# Out:
# Mounted at /content/vdrive

# %%
# Files to process
root_dir = "/content/vdrive/My Drive/Colab Notebooks/Projects/Bondai/SP 500/"
do_file = root_dir + "do_file.csv"
done_file = root_dir + "done_file.csv"
not_done_file = root_dir + "not_done_file.csv"

# Reading the files
import pandas as pd
do_df = pd.read_csv(do_file, header=None, names=["Tickers"])
done_df = pd.read_csv(done_file, header=None, names=["Tickers"])
not_done_df = pd.read_csv(not_done_file, header=None, names=["Tickers"])

do_set = set(do_df["Tickers"].tolist())
done_set = set(done_df["Tickers"].tolist())
not_done_set = set(not_done_df["Tickers"].tolist())

# %%
# URL Paths for Stockrow Website
stockrow_url_paths = {
    'company': 'https://stockrow.com/api/companies/',
    'annual': {
        'income-statement': '/financials.xlsx?dimension=MRY&section=Income%20Statement&sort=desc',
        'balance-sheet': '/financials.xlsx?dimension=MRY&section=Balance%20Sheet&sort=desc',
        'cashflow-statement': '/financials.xlsx?dimension=MRY&section=Cash%20Flow&sort=desc',
        'metrics': '/financials.xlsx?dimension=MRY&section=Metrics&sort=desc',
        'growth': '/financials.xlsx?dimension=MRY&section=Growth&sort=desc'
    } 
}

# Stockrow Downloader
import requests
def stockrow_download(ticker):
    income_statement = pd.read_excel(stockrow_url_paths['company'] + ticker + stockrow_url_paths['annual']["income-statement"], engine="xlrd")
    balance_sheet = pd.read_excel(stockrow_url_paths['company'] + ticker + stockrow_url_paths['annual']["balance-sheet"], engine="xlrd")
    cashflow_statement = pd.read_excel(stockrow_url_paths['company'] + ticker + stockrow_url_paths['annual']["cashflow-statement"], engine="xlrd")
    metrics = pd.read_excel(stockrow_url_paths['company'] + ticker + stockrow_url_paths['annual']["metrics"], engine="xlrd")
    growth = pd.read_excel(stockrow_url_paths['company'] + ticker + stockrow_url_paths['annual']["growth"], engine="xlrd")
    return income_statement, balance_sheet, cashflow_statement, metrics, growth

# %%
# Modified Get Yahoo Quotes Script by Brad Luicas

__author__ = "Brad Luicas"
__copyright__ = "Copyright 2017, Brad Lucas"
__license__ = "MIT"
__version__ = "1.0.0"
__maintainer__ = "Brad Lucas"
__email__ = "brad@beaconhill.com"
__status__ = "Production"

import re
import sys
import time
import datetime
# import requests


def split_crumb_store(v):
    return v.split(':')[2].strip('"')


def find_crumb_store(lines):
    # Looking for
    # ,"CrumbStore":{"crumb":"9q.A4D1c.b9
    for l in lines:
        if re.findall(r'CrumbStore', l):
            return l
    print("Did not find CrumbStore")


def get_cookie_value(r):
    return {'B': r.cookies['B']}


def get_page_data(symbol):
    url = "https://finance.yahoo.com/quote/%s/?p=%s" % (symbol, symbol)
    r = requests.get(url)
    cookie = get_cookie_value(r)

    # Code to replace possible \u002F value
    # ,"CrumbStore":{"crumb":"FWP\u002F5EFll3U"
    # FWP\u002F5EFll3U
    lines = r.content.decode('unicode-escape').strip(). replace('}', '\n')
    return cookie, lines.split('\n')


def get_cookie_crumb(symbol):
    cookie, lines = get_page_data(symbol)
    crumb = split_crumb_store(find_crumb_store(lines))
    return cookie, crumb


def get_data(symbol, start_date, end_date, cookie, crumb):
    # filename = '%s.csv' % (symbol)
    url = "https://query1.finance.yahoo.com/v7/finance/download/%s?period1=%s&period2=%s&interval=1d&events=history&crumb=%s" % (symbol, start_date, end_date, crumb)
    response = requests.get(url, cookies=cookie)
    # with open (filename, 'wb') as handle:
    #     for block in response.iter_content(1024):
    #         handle.write(block)
    return response


def get_now_epoch():
    # @see https://www.linuxquestions.org/questions/programming-9/python-datetime-to-epoch-4175520007/#post5244109
    return int(time.time())


def download_quotes(symbol):
    start_date = 0
    end_date = get_now_epoch()
    cookie, crumb = get_cookie_crumb(symbol)
    historical_prices = get_data(symbol, start_date, end_date, cookie, crumb)
    return pd.read_csv(io.StringIO(historical_prices.content.decode('utf-8')))

# %%
import os
import io
def main():
    counter = 0
    total = len(do_set)
    
    print(do_set)
    for ticker in do_set.copy():
        counter = counter + 1
        try:
            print("Downloading data for: " + ticker + "(" + str(counter) + "/" + str(total) +"); Failed(" + str(len(not_done_set)) + ")")
            income_statement, balance_sheet, cashflow_statement, metrics, growth = stockrow_download(ticker)
            historical_prices = download_quotes(ticker)
            with pd.ExcelWriter(root_dir + "data/" + ticker + '.xlsx') as writer:
                historical_prices.to_excel(writer, sheet_name="historical_prices")
                balance_sheet.to_excel(writer, sheet_name="balance_sheet")
                income_statement.to_excel(writer, sheet_name="income_statement")
                cashflow_statement.to_excel(writer, sheet_name="cashflow_statement")
                metrics.to_excel(writer, sheet_name="metrics")
                growth.to_excel(writer, sheet_name="growth")
        except:
            not_done_set.add(ticker)
            do_set.discard(ticker)
            pd.DataFrame(list(not_done_set)).to_csv(not_done_file, header=None, index=False)
            pd.DataFrame(list(do_set)).to_csv(do_file, header=None, index=False)
            continue
            
            
        done_set.add(ticker)
        do_set.discard(ticker)
        pd.DataFrame(list(done_set)).to_csv(done_file, header=None, index=False)
        pd.DataFrame(list(not_done_set)).to_csv(not_done_file, header=None, index=False)
        pd.DataFrame(list(do_set)).to_csv(do_file, header=None, index=False)

# %%
main()
# Out:
# {'NFX', 'JWN', 'BKNG', 'ALLE', 'JBHT', 'WELL', 'HON', 'DISCA', 'AEP', 'XOM', 'XEC', 'NTAP', 'AMP', 'MYL', 'LEN', 'AVB', 'VFC', 'BHF', 'DVN', 'HRB', 'SIVB', 'COTY', 'UDR', 'KSS', 'PXD', 'URI', 'IR', 'WYNN', 'VNO', 'KLAC', 'BSX', 'PM', 'SWKS', 'SLB', 'AAPL', 'AMG', 'CMI', 'T', 'TEL', 'CTSH', 'AMGN', 'MSI', 'WHR', 'AYI', 'WFC', 'RRC', 'COST', 'PSX', 'RSG', 'DAL', 'AJG', 'PWR', 'GOOG', 'IFF', 'MRK', 'ICE', 'SYY', 'UNP', 'FBHS', 'SBAC', 'WLTW', 'ABT', 'ARE', 'IDXX', 'AEE', 'AXP', 'BK', 'MS', 'INTU', 'KIM', 'PVH', 'WDC', 'APA', 'MAA', 'TJX', 'FDX', 'JEC', 'QCOM', 'CSRA', 'NUE', 'TROW', 'XEL', 'V', 'ADI', 'CVX', 'NKE', 'ZION', 'SNA', 'UTX', 'RMD', 'GGP', 'KHC', 'XRX', 'KSU', 'EBAY', 'SO', 'OMC', 'CHRW', 'HRL', 'PEG', 'DGX', 'PX', 'CSCO', 'LRCX', 'HII', 'NAVI', 'FMC', 'LMT', 'NEM', 'TMO', 'CHD', 'PNW', 'AVGO', 'KEY', 'ACN', 'ESS', 'TSN', 'HD', 'PCG', 'ANDV', 'HES', 'SYMC', 'ALL', 'TPR', 'JNJ', 'MSFT', 'DISH', 'GRMN', 'EXPE', 'CBOE', 'WYN', 'COL', 'M', 'L', 'AKAM', 'DUK', 'GILD', 'KORS', 'LH', 'APTV', 'CCL', 'STX', 'PFG', 'MCK', 'RHT', 'TRV', 'FE', 'NWL', 'TXT', 'LOW', 'HOG', 'CTAS', 'TIF', 'MON', 'IBM', 'SPG', 'FTI', 'MAT', 'COP', 'FTV', 'CINF', 'MTD', 'PSA', 'ANTM', 'TRIP', 'MCD', 'INCY', 'ARNC', 'ZBH', 'ROST', 'CXO', 'MLM', 'HOLX', 'SLG', 'HBAN', 'IRM', 'DOV', 'WBA', 'FISV', 'NKTR', 'INTC', 'XL', 'DTE', 'DISCK', 'HAL', 'FAST', 'EL', 'A', 'LNC', 'GLW', 'NRG', 'SYK', 'ADBE', 'DWDP', 'DRI', 'MDT', 'CMG', 'FITB', 'REGN', 'MHK', 'WMT', 'UNH', 'BIIB', 'PKI', 'EQIX', 'FFIV', 'ALB', 'SCG', 'PRU', 'AAL', 'EFX', 'AOS', 'CPB', 'BF.B', 'AMD', 'ESRX', 'NVDA', 'JNPR', 'DLR', 'BEN', 'IPGP', 'BLL', 'PCAR', 'COO', 'HCA', 'CMS', 'IVZ', 'PH', 'TAP', 'VAR', 'BHGE', 'AET', 'BRK.B', 'VTR', 'JCI', 'VRSN', 'SJM', 'HPQ', 'SYF', 'SWK', 'AES', 'HP', 'BMY', 'RL', 'NLSN', 'CBS', 'ROP', 'TXN', 'AIV', 'NFLX', 'PBCT', 'UAL', 'ATVI', 'UNM', 'USB', 'KMX', 'UHS', 'ADSK', 'HCP', 'CAT', 'AME', 'AON', 'AIZ', 'LNT', 'FOXA', 'CCI', 'AMT', 'MAS', 'GE', 'WY', 'QRVO', 'LUK', 'EQT', 'MAC', 'VRSK', 'MOS', 'ROK', 'UPS', 'FB', 'UAA', 'NDAQ', 'DHR', 'ES', 'PPL', 'CMCSA', 'EMN', 'ITW', 'DFS', 'CLX', 'PYPL', 'GPN', 'CBRE', 'ADS', 'CERN', 'APC', 'FRT', 'ANSS', 'AMZN', 'DXC', 'NBL', 'FIS', 'TDG', 'HST', 'MCHP', 'AVY', 'SCHW', 'DE', 'PHM', 'CDNS', 'O', 'XLNX', 'LUV', 'HPE', 'HIG', 'PAYX', 'PG', 'ETN', 'MU', 'K', 'FLR', 'ECL', 'BWA', 'MRO', 'VLO', 'DHI', 'LLL', 'GIS', 'DLTR', 'STT', 'MGM', 'LLY', 'BDX', 'VRTX', 'MTB', 'EXPD', 'BAX', 'HRS', 'BAC', 'GPC', 'CME', 'HAS', 'CNP', 'FLS', 'HLT', 'TSCO', 'SRCL', 'MNST', 'EXR', 'IQV', 'XRAY', 'VZ', 'ULTA', 'NCLH', 'PLD', 'ABBV', 'PEP', 'PFE', 'XYL', 'SRE', 'WEC', 'OKE', 'NWS', 'BXP', 'NSC', 'COG', 'OXY', 'EA', 'GM', 'BA', 'SBUX', 'PKG', 'KO', 'CFG', 'NOC', 'EOG'}
# Downloading data for: NFX(1/375); Failed(0)
# Downloading data for: JWN(2/375); Failed(1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: invalid escape sequence '\/'
# Downloading data for: BKNG(3/375); Failed(1)
# Downloading data for: XL(4/375); Failed(1)
# Downloading data for: DTE(5/375); Failed(2)
# Downloading data for: ALLE(6/375); Failed(2)
# Downloading data for: DISCK(7/375); Failed(2)
# Downloading data for: HAL(8/375); Failed(2)
# Downloading data for: JBHT(9/375); Failed(2)
# Downloading data for: FAST(10/375); Failed(2)
# Downloading data for: EL(11/375); Failed(2)
# Downloading data for: A(12/375); Failed(2)
# Downloading data for: LNC(13/375); Failed(2)
# Downloading data for: WELL(14/375); Failed(2)
# Downloading data for: HON(15/375); Failed(2)
# Downloading data for: DISCA(16/375); Failed(2)
# Downloading data for: AEP(17/375); Failed(2)
# Downloading data for: XOM(18/375); Failed(2)
# Downloading data for: XEC(19/375); Failed(2)
# Downloading data for: GLW(20/375); Failed(2)
# Downloading data for: NRG(21/375); Failed(2)
# Downloading data for: NTAP(22/375); Failed(2)
# Downloading data for: AMP(23/375); Failed(2)
# Downloading data for: SYK(24/375); Failed(2)
# Downloading data for: MYL(25/375); Failed(3)
# Downloading data for: ADBE(26/375); Failed(3)
# Downloading data for: LEN(27/375); Failed(3)
# Downloading data for: DWDP(28/375); Failed(3)
# Downloading data for: DRI(29/375); Failed(3)
# Downloading data for: MDT(30/375); Failed(3)
# Downloading data for: CMG(31/375); Failed(3)
# Downloading data for: FITB(32/375); Failed(3)
# Downloading data for: REGN(33/375); Failed(3)
# Downloading data for: AVB(34/375); Failed(3)
# Downloading data for: VFC(35/375); Failed(3)
# Downloading data for: BHF(36/375); Failed(3)
# Downloading data for: MHK(37/375); Failed(3)
# Downloading data for: DVN(38/375); Failed(3)
# Downloading data for: WMT(39/375); Failed(3)
# Downloading data for: UNH(40/375); Failed(3)
# Downloading data for: BIIB(41/375); Failed(3)
# Downloading data for: PKI(42/375); Failed(3)
# Downloading data for: HRB(43/375); Failed(3)
# Downloading data for: EQIX(44/375); Failed(3)
# Downloading data for: FFIV(45/375); Failed(3)
# Downloading data for: ALB(46/375); Failed(3)
# Downloading data for: SIVB(47/375); Failed(3)
# Downloading data for: COTY(48/375); Failed(3)
# Downloading data for: SCG(49/375); Failed(3)
# Downloading data for: UDR(50/375); Failed(4)
# Downloading data for: KSS(51/375); Failed(4)
# Downloading data for: PRU(52/375); Failed(4)
# Downloading data for: PXD(53/375); Failed(4)
# Downloading data for: URI(54/375); Failed(4)
# Downloading data for: AAL(55/375); Failed(4)
# Downloading data for: EFX(56/375); Failed(4)
# Downloading data for: IR(57/375); Failed(4)
# Downloading data for: WYNN(58/375); Failed(4)
# Downloading data for: VNO(59/375); Failed(4)
# Downloading data for: AOS(60/375); Failed(4)
# Downloading data for: KLAC(61/375); Failed(4)
# Downloading data for: CPB(62/375); Failed(4)
# Downloading data for: BSX(63/375); Failed(4)
# Downloading data for: PM(64/375); Failed(4)
# Downloading data for: SWKS(65/375); Failed(4)
# Downloading data for: BF.B(66/375); Failed(4)
# Downloading data for: SLB(67/375); Failed(5)
# Downloading data for: AAPL(68/375); Failed(5)
# Downloading data for: AMG(69/375); Failed(5)
# Downloading data for: AMD(70/375); Failed(5)
# Downloading data for: CMI(71/375); Failed(5)
# Downloading data for: ESRX(72/375); Failed(5)
# Downloading data for: T(73/375); Failed(6)
# Downloading data for: TEL(74/375); Failed(6)
# Downloading data for: NVDA(75/375); Failed(6)
# Downloading data for: JNPR(76/375); Failed(6)
# Downloading data for: CTSH(77/375); Failed(6)
# Downloading data for: AMGN(78/375); Failed(6)
# Downloading data for: DLR(79/375); Failed(6)
# Downloading data for: BEN(80/375); Failed(6)
# Downloading data for: MSI(81/375); Failed(6)
# Downloading data for: WHR(82/375); Failed(6)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: DeprecationWarning: invalid escape sequence '\.'
# Downloading data for: AYI(83/375); Failed(6)
# Downloading data for: IPGP(84/375); Failed(6)
# Downloading data for: BLL(85/375); Failed(6)
# Downloading data for: PCAR(86/375); Failed(6)
# Downloading data for: COO(87/375); Failed(6)
# Downloading data for: WFC(88/375); Failed(6)
# Downloading data for: RRC(89/375); Failed(6)
# Downloading data for: HCA(90/375); Failed(6)
# Downloading data for: COST(91/375); Failed(6)
# Downloading data for: PSX(92/375); Failed(6)
# Downloading data for: CMS(93/375); Failed(6)
# Downloading data for: RSG(94/375); Failed(6)
# Downloading data for: DAL(95/375); Failed(6)
# Downloading data for: IVZ(96/375); Failed(6)
# Downloading data for: AJG(97/375); Failed(6)
# Downloading data for: PWR(98/375); Failed(6)
# Downloading data for: GOOG(99/375); Failed(6)
# Downloading data for: IFF(100/375); Failed(6)
# Downloading data for: MRK(101/375); Failed(6)
# Downloading data for: ICE(102/375); Failed(6)
# Downloading data for: SYY(103/375); Failed(6)
# Downloading data for: UNP(104/375); Failed(6)
# Downloading data for: PH(105/375); Failed(7)
# Downloading data for: TAP(106/375); Failed(7)
# Downloading data for: VAR(107/375); Failed(7)
# Downloading data for: BHGE(108/375); Failed(7)
# Downloading data for: FBHS(109/375); Failed(7)
# Downloading data for: SBAC(110/375); Failed(7)
# Downloading data for: WLTW(111/375); Failed(7)
# Downloading data for: ABT(112/375); Failed(7)
# Downloading data for: AET(113/375); Failed(7)
# Downloading data for: ARE(114/375); Failed(8)
# Downloading data for: BRK.B(115/375); Failed(8)
# Downloading data for: VTR(116/375); Failed(9)
# Downloading data for: JCI(117/375); Failed(9)
# Downloading data for: IDXX(118/375); Failed(9)
# Downloading data for: AEE(119/375); Failed(9)
# Downloading data for: AXP(120/375); Failed(9)
# Downloading data for: VRSN(121/375); Failed(9)
# Downloading data for: SJM(122/375); Failed(9)
# Downloading data for: BK(123/375); Failed(9)
# Downloading data for: HPQ(124/375); Failed(9)
# Downloading data for: SYF(125/375); Failed(9)
# Downloading data for: MS(126/375); Failed(9)
# Downloading data for: SWK(127/375); Failed(9)
# Downloading data for: INTU(128/375); Failed(9)
# Downloading data for: AES(129/375); Failed(9)
# Downloading data for: HP(130/375); Failed(9)
# Downloading data for: KIM(131/375); Failed(9)
# Downloading data for: BMY(132/375); Failed(9)
# Downloading data for: PVH(133/375); Failed(9)
# Downloading data for: RL(134/375); Failed(9)
# Downloading data for: WDC(135/375); Failed(9)
# Downloading data for: NLSN(136/375); Failed(9)
# Downloading data for: CBS(137/375); Failed(9)
# Downloading data for: ROP(138/375); Failed(9)
# Downloading data for: TXN(139/375); Failed(9)
# Downloading data for: AIV(140/375); Failed(9)
# Downloading data for: APA(141/375); Failed(9)
# Downloading data for: NFLX(142/375); Failed(9)
# Downloading data for: PBCT(143/375); Failed(9)
# Downloading data for: MAA(144/375); Failed(9)
# Downloading data for: TJX(145/375); Failed(9)
# Downloading data for: UAL(146/375); Failed(9)
# Downloading data for: FDX(147/375); Failed(9)
# Downloading data for: JEC(148/375); Failed(9)
# Downloading data for: ATVI(149/375); Failed(9)
# Downloading data for: UNM(150/375); Failed(9)
# Downloading data for: USB(151/375); Failed(9)
# Downloading data for: KMX(152/375); Failed(9)
# Downloading data for: QCOM(153/375); Failed(9)
# Downloading data for: UHS(154/375); Failed(9)
# Downloading data for: CSRA(155/375); Failed(9)
# Downloading data for: ADSK(156/375); Failed(10)
# Downloading data for: HCP(157/375); Failed(10)
# Downloading data for: CAT(158/375); Failed(10)
# Downloading data for: NUE(159/375); Failed(10)
# Downloading data for: AME(160/375); Failed(10)
# Downloading data for: TROW(161/375); Failed(10)
# Downloading data for: AON(162/375); Failed(10)
# Downloading data for: XEL(163/375); Failed(10)
# Downloading data for: V(164/375); Failed(10)
# Downloading data for: AIZ(165/375); Failed(10)
# Downloading data for: ADI(166/375); Failed(10)
# Downloading data for: LNT(167/375); Failed(10)
# Downloading data for: FOXA(168/375); Failed(10)
# Downloading data for: CVX(169/375); Failed(10)
# Downloading data for: CCI(170/375); Failed(10)
# Downloading data for: NKE(171/375); Failed(10)
# Downloading data for: ZION(172/375); Failed(10)
# Downloading data for: AMT(173/375); Failed(10)
# Downloading data for: MAS(174/375); Failed(10)
# Downloading data for: SNA(175/375); Failed(10)
# Downloading data for: GE(176/375); Failed(10)
# Downloading data for: UTX(177/375); Failed(10)
# Downloading data for: WY(178/375); Failed(10)
# Downloading data for: RMD(179/375); Failed(10)
# Downloading data for: GGP(180/375); Failed(10)
# Downloading data for: QRVO(181/375); Failed(11)
# Downloading data for: KHC(182/375); Failed(11)
# Downloading data for: LUK(183/375); Failed(11)
# Downloading data for: XRX(184/375); Failed(12)
# Downloading data for: EQT(185/375); Failed(12)
# Downloading data for: MAC(186/375); Failed(12)
# Downloading data for: VRSK(187/375); Failed(12)
# Downloading data for: MOS(188/375); Failed(12)
# Downloading data for: ROK(189/375); Failed(12)
# Downloading data for: UPS(190/375); Failed(12)
# Downloading data for: FB(191/375); Failed(12)
# Downloading data for: UAA(192/375); Failed(12)
# Downloading data for: KSU(193/375); Failed(12)
# Downloading data for: EBAY(194/375); Failed(12)
# Downloading data for: NDAQ(195/375); Failed(12)
# Downloading data for: DHR(196/375); Failed(12)
# Downloading data for: ES(197/375); Failed(12)
# Downloading data for: PPL(198/375); Failed(12)
# Downloading data for: SO(199/375); Failed(12)
# Downloading data for: CMCSA(200/375); Failed(12)
# Downloading data for: EMN(201/375); Failed(12)
# Downloading data for: ITW(202/375); Failed(12)
# Downloading data for: OMC(203/375); Failed(12)
# Downloading data for: CHRW(204/375); Failed(12)
# Downloading data for: HRL(205/375); Failed(12)
# Downloading data for: DFS(206/375); Failed(13)
# Downloading data for: CLX(207/375); Failed(13)
# Downloading data for: PEG(208/375); Failed(13)
# Downloading data for: DGX(209/375); Failed(13)
# Downloading data for: PX(210/375); Failed(13)
# Downloading data for: PYPL(211/375); Failed(14)
# Downloading data for: CSCO(212/375); Failed(14)
# Downloading data for: GPN(213/375); Failed(14)
# Downloading data for: CBRE(214/375); Failed(14)
# Downloading data for: LRCX(215/375); Failed(14)
# Downloading data for: ADS(216/375); Failed(14)
# Downloading data for: HII(217/375); Failed(14)
# Downloading data for: CERN(218/375); Failed(14)
# Downloading data for: NAVI(219/375); Failed(14)
# Downloading data for: FMC(220/375); Failed(14)
# Downloading data for: LMT(221/375); Failed(14)
# Downloading data for: APC(222/375); Failed(14)
# Downloading data for: FRT(223/375); Failed(14)
# Downloading data for: ANSS(224/375); Failed(14)
# Downloading data for: NEM(225/375); Failed(14)
# Downloading data for: TMO(226/375); Failed(14)
# Downloading data for: CHD(227/375); Failed(14)
# Downloading data for: PNW(228/375); Failed(14)
# Downloading data for: AMZN(229/375); Failed(14)
# Downloading data for: DXC(230/375); Failed(14)
# Downloading data for: NBL(231/375); Failed(14)
# Downloading data for: AVGO(232/375); Failed(14)
# Downloading data for: FIS(233/375); Failed(14)
# Downloading data for: TDG(234/375); Failed(14)
# Downloading data for: KEY(235/375); Failed(14)
# Downloading data for: HST(236/375); Failed(14)
# Downloading data for: MCHP(237/375); Failed(14)
# Downloading data for: ACN(238/375); Failed(14)
# Downloading data for: AVY(239/375); Failed(14)
# Downloading data for: SCHW(240/375); Failed(14)
# Downloading data for: DE(241/375); Failed(14)
# Downloading data for: ESS(242/375); Failed(14)
# Downloading data for: PHM(243/375); Failed(14)
# Downloading data for: TSN(244/375); Failed(14)
# Downloading data for: CDNS(245/375); Failed(14)
# Downloading data for: O(246/375); Failed(14)
# Downloading data for: HD(247/375); Failed(14)
# Downloading data for: PCG(248/375); Failed(14)
# Downloading data for: ANDV(249/375); Failed(14)
# Downloading data for: XLNX(250/375); Failed(15)
# Downloading data for: LUV(251/375); Failed(15)
# Downloading data for: HES(252/375); Failed(15)
# Downloading data for: SYMC(253/375); Failed(15)
# Downloading data for: ALL(254/375); Failed(15)
# Downloading data for: HPE(255/375); Failed(15)
# Downloading data for: HIG(256/375); Failed(15)
# Downloading data for: PAYX(257/375); Failed(15)
# Downloading data for: PG(258/375); Failed(15)
# Downloading data for: TPR(259/375); Failed(15)
# Downloading data for: JNJ(260/375); Failed(15)
# Downloading data for: ETN(261/375); Failed(15)
# Downloading data for: MSFT(262/375); Failed(15)
# Downloading data for: DISH(263/375); Failed(15)
# Downloading data for: MU(264/375); Failed(15)
# Downloading data for: GRMN(265/375); Failed(15)
# Downloading data for: EXPE(266/375); Failed(15)
# Downloading data for: CBOE(267/375); Failed(15)
# Downloading data for: WYN(268/375); Failed(15)
# Downloading data for: K(269/375); Failed(16)
# Downloading data for: FLR(270/375); Failed(16)
# Downloading data for: COL(271/375); Failed(16)
# Downloading data for: ECL(272/375); Failed(17)
# Downloading data for: M(273/375); Failed(17)
# Downloading data for: L(274/375); Failed(17)
# Downloading data for: AKAM(275/375); Failed(17)
# Downloading data for: BWA(276/375); Failed(17)
# Downloading data for: MRO(277/375); Failed(17)
# Downloading data for: VLO(278/375); Failed(17)
# Downloading data for: DHI(279/375); Failed(17)
# Downloading data for: DUK(280/375); Failed(17)
# Downloading data for: LLL(281/375); Failed(17)
# Downloading data for: GILD(282/375); Failed(17)
# Downloading data for: GIS(283/375); Failed(17)
# Downloading data for: KORS(284/375); Failed(17)
# Downloading data for: LH(285/375); Failed(18)
# Downloading data for: APTV(286/375); Failed(18)
# Downloading data for: DLTR(287/375); Failed(18)
# Downloading data for: STT(288/375); Failed(18)
# Downloading data for: MGM(289/375); Failed(18)
# Downloading data for: CCL(290/375); Failed(18)
# Downloading data for: STX(291/375); Failed(18)
# Downloading data for: LLY(292/375); Failed(18)
# Downloading data for: BDX(293/375); Failed(18)
# Downloading data for: PFG(294/375); Failed(18)
# Downloading data for: MCK(295/375); Failed(18)
# Downloading data for: VRTX(296/375); Failed(18)
# Downloading data for: RHT(297/375); Failed(18)
# Downloading data for: MTB(298/375); Failed(18)
# Downloading data for: EXPD(299/375); Failed(18)
# Downloading data for: BAX(300/375); Failed(18)
# Downloading data for: HRS(301/375); Failed(18)
# Downloading data for: BAC(302/375); Failed(18)
# Downloading data for: TRV(303/375); Failed(18)
# Downloading data for: FE(304/375); Failed(18)
# Downloading data for: NWL(305/375); Failed(18)
# Downloading data for: GPC(306/375); Failed(18)
# Downloading data for: CME(307/375); Failed(18)
# Downloading data for: HAS(308/375); Failed(18)
# Downloading data for: TXT(309/375); Failed(18)
# Downloading data for: LOW(310/375); Failed(18)
# Downloading data for: HOG(311/375); Failed(18)
# Downloading data for: CNP(312/375); Failed(18)
# Downloading data for: FLS(313/375); Failed(18)
# Downloading data for: HLT(314/375); Failed(18)
# Downloading data for: TSCO(315/375); Failed(18)
# Downloading data for: CTAS(316/375); Failed(18)
# Downloading data for: SRCL(317/375); Failed(18)
# Downloading data for: TIF(318/375); Failed(18)
# Downloading data for: MON(319/375); Failed(18)
# Downloading data for: MNST(320/375); Failed(19)
# Downloading data for: EXR(321/375); Failed(19)
# Downloading data for: IQV(322/375); Failed(19)
# Downloading data for: IBM(323/375); Failed(19)
# Downloading data for: SPG(324/375); Failed(19)
# Downloading data for: XRAY(325/375); Failed(19)
# Downloading data for: VZ(326/375); Failed(19)
# Downloading data for: ULTA(327/375); Failed(19)
# Downloading data for: NCLH(328/375); Failed(19)
# Downloading data for: FTI(329/375); Failed(19)
# Downloading data for: MAT(330/375); Failed(19)
# Downloading data for: PLD(331/375); Failed(19)
# Downloading data for: COP(332/375); Failed(19)
# Downloading data for: FTV(333/375); Failed(19)
# Downloading data for: CINF(334/375); Failed(19)
# Downloading data for: ABBV(335/375); Failed(19)
# Downloading data for: PEP(336/375); Failed(19)
# Downloading data for: MTD(337/375); Failed(19)
# Downloading data for: PSA(338/375); Failed(19)
# Downloading data for: PFE(339/375); Failed(19)
# Downloading data for: XYL(340/375); Failed(19)
# Downloading data for: SRE(341/375); Failed(19)
# Downloading data for: WEC(342/375); Failed(19)
# Downloading data for: ANTM(343/375); Failed(19)
# Downloading data for: TRIP(344/375); Failed(19)
# Downloading data for: OKE(345/375); Failed(19)
# Downloading data for: MCD(346/375); Failed(19)
# Downloading data for: INCY(347/375); Failed(19)
# Downloading data for: ARNC(348/375); Failed(19)
# Downloading data for: NWS(349/375); Failed(19)
# Downloading data for: ZBH(350/375); Failed(19)
# Downloading data for: BXP(351/375); Failed(19)
# Downloading data for: ROST(352/375); Failed(19)
# Downloading data for: CXO(353/375); Failed(19)
# Downloading data for: MLM(354/375); Failed(19)
# Downloading data for: NSC(355/375); Failed(19)
# Downloading data for: COG(356/375); Failed(19)
# Downloading data for: OXY(357/375); Failed(19)
# Downloading data for: EA(358/375); Failed(19)
# Downloading data for: GM(359/375); Failed(19)
# Downloading data for: HOLX(360/375); Failed(19)
# Downloading data for: SLG(361/375); Failed(19)
# Downloading data for: HBAN(362/375); Failed(19)
# Downloading data for: IRM(363/375); Failed(19)
# Downloading data for: BA(364/375); Failed(19)
# Downloading data for: DOV(365/375); Failed(19)
# Downloading data for: SBUX(366/375); Failed(19)
# Downloading data for: PKG(367/375); Failed(19)
# Downloading data for: KO(368/375); Failed(19)
# Downloading data for: CFG(369/375); Failed(19)
# Downloading data for: WBA(370/375); Failed(19)
# Downloading data for: NOC(371/375); Failed(19)
# Downloading data for: EOG(372/375); Failed(19)
# Downloading data for: FISV(373/375); Failed(19)
# Downloading data for: NKTR(374/375); Failed(19)
# Downloading data for: INTC(375/375); Failed(19)
