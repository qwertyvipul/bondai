# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array([
    (1,10),(2,12),(3,14),(4,16),
    (5,17),(6,18),(7,19),(8,20),
    (9,19),(10,18),(11,17),(12,20),
    (13,10),(14,12),(15,13),(16,14),
    (17,10),(18,12),(19,14),(20,16),
    (21,10),(22,12),(23,13),(24,14),
    (25,19),(26,18),(27,17),(28,20),
    (29,17),(30,18),(31,19),(32,20)
])

x = data[:,0]
y = data[:,1]
# z = np.polyfit(x,y,6)

# plt.figure(1)
# plt.subplot(411)
# plt.plot(x)

# plt.subplot(412)
# plt.plot(y)

# plt.subplot(413)
plt.plot(x, y)
# plt.show()

# plt.subplot(414)
# plt.plot(z)
# plt.show()


plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), 'r')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 3))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 3))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 4))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(x,y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 4))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 5))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 5))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 6))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(x,y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 6))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 7))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 7))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 8))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 8))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 9))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 9))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 10))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 10))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 11))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 11))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 12))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 12))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 13))(np.unique(x)), 'g')
plt.show()

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 13))(np.unique(x)), 'r')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 14))(np.unique(x)), 'g')
plt.show()
