# %%
import pandas as pd
import numpy as np

file_path = "../../data/company-list/"

# %%
nasdaq_list = set(pd.read_csv(file_path + "nasdaq.csv")["Symbol"])
nasdaq_list
# Out:
# {'CENT',
#  'VVUS',
#  'LSXMB',
#  'NTCT',
#  'MDCO',
#  'KCAP',
#  'CIVB',
#  'PTEN',
#  'TIBRU',
#  'ORMP',
#  'PDP',
#  'LAKE',
#  'BOSC',
#  'EVLMC',
#  'EBTC',
#  'GPP',
#  'IFGL',
#  'CTXRW',
#  'KALA',
#  'NYMTO',
#  'NWSA',
#  'STIM',
#  'AAXJ',
#  'ZIOP',
#  'RCKT',
#  'SPRO',
#  'OKDCC',
#  'GBLI',
#  'CTRL',
#  'FIXD',
#  'ZAGG',
#  'FORM',
#  'USWSW',
#  'CCRN',
#  'FNKO',
#  'SXTC',
#  'GFNCP',
#  'VTWO',
#  'DDBI',
#  'ACHN',
#  'FOANC',
#  'OPB',
#  'FOX',
#  'FHB',
#  'ALGRU',
#  'MOGLC',
#  'EVOP',
#  'COLM',
#  'LOOP',
#  'TANH',
#  'FPXI',
#  'TBBK',
#  'EXLS',
#  'SKYS',
#  'SSNT',
#  'TAIT',
#  'IQ',
#  'WORX',
#  'RDVT',
#  'MFNC',
#  'CNXN',
#  'GECCL',
#  'OPNT',
#  'AUPH',
#  'PETS',
#  'FBZ',
#  'ICUI',
#  'STKS',
#  'ATOS',
#  'TRMB',
#  'UMBF',
#  'PEBK',
#  'GULF',
#  'EVGBC',
#  'TESS',
#  'FOSL',
#  'CRON',
#  'NCTY',
#  'AGIO',
#  'MOR',
#  'ASTE',
#  'EXPD',
#  'SCAC',
#  'KGJI',
#  'FFBC',
#  'ABUS',
#  'MCFT',
#  'OCSL',
#  'FIVN',
#  'EDGE',
# ...

# %%
import pickle

with open(file_path + 'nasdaq_list.pickle', 'wb') as fp:
    pickle.dump(nasdaq_list, fp)

# %%
with open ('outfile', 'rb') as fp:
    itemlist = pickle.load(fp)
    print(itemlist)
# Out:
# ['YI', 'PIH', 'PIHPP', 'TURN', 'FLWS', 'BCOW', 'FCCY', 'SRCE', 'VNET', 'TWOU', 'QFIN', 'TPNL', 'JOBS', 'EGHT', 'AAON', 'ABEO', 'ABEOW', 'ABIL', 'ABMD', 'AXAS', 'ACIU', 'ACIA', 'ACTG', 'ACHC', 'ACAD', 'ACAMU', 'ACST', 'AXDX', 'XLRN', 'ARAY', 'ACRX', 'ACER', 'ACET', 'AKAO', 'ACHV', 'ACHN', 'ACIW', 'ACRS', 'ACMR', 'ACNB', 'ACOR', 'ATVI', 'ADMS', 'ADMP', 'ADAP', 'ADUS', 'AEY', 'IOTS', 'ADIL', 'ADILW', 'ADMA', 'ADBE', 'ADOM', 'ADTN', 'ADRO', 'ADES', 'AEIS', 'AMD', 'ADXS', 'ADVM', 'DWMC', 'DWSH', 'BKCH', 'ACT', 'AEGN', 'AGLE', 'AEHR', 'AMTX', 'AERI', 'AVAV', 'ARPO', 'AEZS', 'AEMD', 'GNMX', 'AFMD', 'AGEN', 'AGRX', 'AGYS', 'AGIO', 'AGMH', 'AGNC', 'AGNCB', 'AGNCN', 'AGFS', 'AGFSW', 'ALRN', 'AIMT', 'AIRT', 'ATSG', 'AIRG', 'AMCN', 'AKAM', 'AKTX', 'AKCA', 'AKBA', 'AKER', 'AKRX', 'AKTS', 'ALRM', 'ALSK', 'ALAC', 'ALACR', 'ALACU', 'ALACW', 'ALBO', 'ABDC', 'ALDR', 'ALDX', 'ALEC', 'ALXN', 'ALCO', 'ALGN', 'ALIM', 'ALYA', 'ALJJ', 'ALKS', 'ALLK', 'ABTX', 'ALGT', 'ALGR', 'ALGRR', 'ALGRU', 'ALGRW', 'ALNA'
# ...
